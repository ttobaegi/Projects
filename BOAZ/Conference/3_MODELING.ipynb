# %%
import pandas as pd

# %%
import re

# %%
data = pd.read_csv('과학데이터최종진짜.csv',encoding='utf-8',index_col=0)

# %%
data
# Out:
#           지은이                                              story women10  \
# 0         정재승  영원한 탐구 대상인 ‘인간’이라는 숲을 이해하기 위해 미지의 탐험을 떠난 과학자들이...    1.1%
# 1       호프 자런  P. 49 시간은 나, 내 나무에 대한 나의 눈, 그리고 내 나무가 자신을 보는 눈...    1.1%
# 2       칼 세이건  탐험의 욕구는 인간의 본성이다. 우리는 나그네로 시작했으며 나그네로 남아 있다. 인...    1.7%
# 3      앨릭스 코브  뇌는 계속해서 우울한 상태를 유지하는 방향으로 생각하고 행동하는 경향이 있다. 우울...    3.2%
# 4         김민형  지금 우리에게 다소 어려운 문제들도 언젠가는 상식이 될 것입니다. 오늘날 인간이 가...    2.0%
# ..        ...                                                ...     ...
# 303       전중환  현대 사회와 현대 도시인의 일상을 통해 마음과 본능 욕망의 진짜 얼굴을 낱낱이 파헤...    2.0%
# 304  후쿠오카 신이치  "사실 고등동물의 경우는 그들이 질서 정연한 것들을 먹이로 삼고 있다는 것을 우리는...    4.6%
# 305       안소정  그동안 쉽고 재미있는 수학 이야기로 독자와 친근하게 소통했던 안소영 저자는 이번 책...    3.7%
# 306    라파엘 로젠  브로콜리에서 프랙털을 빗방울에서 기하학을 종소리에서 순열을 발견할 수 있는 흥미로운...    3.8%
# 307     약학정보원  적합한 OTC를 단시간 내에 선택 및 복약지도를 해야 하는 약사를 위한 일반의약품 ...      0%
#
#     men10 women20  men20 women30  men30 women40  men40 women50  men50 women60  \
# 0    0.4%    8.9%   3.2%   17.7%   6.8%   32.4%  10.4%   10.9%   6.2%    0.9%
# 1    0.2%   13.2%   2.3%   25.4%   4.6%   28.3%   7.0%   10.5%   4.9%    1.2%
# 2    1.8%   10.7%   7.0%   16.4%  13.6%   23.1%  15.8%    4.0%   4.8%    0.4%
# 3    0.3%   26.1%   5.2%   22.6%   6.7%   17.5%   7.0%    5.5%   4.2%    0.7%
# 4    1.3%    5.4%   4.1%   14.6%   8.6%   31.5%  14.8%    7.3%   8.5%    0.5%
# ..    ...     ...    ...     ...    ...     ...    ...     ...    ...     ...
# 303  0.9%    4.8%   3.7%    9.3%   8.2%   30.1%  21.1%    6.4%  11.5%    0.6%
# 304  3.8%    5.6%   2.9%    8.3%  10.7%   30.1%  18.5%    5.2%   9.2%    0.2%
# 305  1.8%    2.0%   1.7%    5.7%   1.7%   56.5%  13.4%    6.9%   5.8%    0.4%
# 306  1.9%    3.8%   2.6%    9.6%   7.0%   40.0%  17.4%    6.6%   6.3%    0.1%
# 307    0%   24.5%  11.9%   24.3%  13.4%   10.5%   6.7%    5.9%   1.9%    0.6%
#
#     men60 category               name          ISBN   publish      date
# 0    1.2%       과학             열두 발자국  9.791161e+12      어크로스  20180702
# 1    1.3%       과학                랩 걸  9.791160e+12        알마  20170217
# 2    0.7%       과학               코스모스  9.788984e+12    사이언스북스  20041220
# 3    1.0%       과학          우울할 땐 뇌과학  9.791157e+12        심심  20180312
# 4    1.3%       과학         수학이 필요한 순간  9.791187e+12  인플루엔셜(주)  20180803
# ..    ...      ...                ...           ...       ...       ...
# 303  1.4%       과학            오래된 연장통  9.788984e+12    사이언스북스  20100115
# 304  0.9%       과학         생물과 무생물 사이  9.788957e+12      은행나무  20080613
# 305  0.2%       과학         배낭에서 꺼낸 수학  9.788959e+12     휴머니스트  20111226
# 306  1.1%       과학  세상을 움직이는 수학개념 100  9.791185e+12        반니  20160329
# 307  0.4%       과학       맞춤 OTC 선택가이드  9.788991e+12  조윤커뮤니케이션  20160315
#
# [297 rows x 19 columns]

# %%
data['story'][0]
# Out:
# '영원한 탐구 대상인 ‘인간’이라는 숲을 이해하기 위해 미지의 탐험을 떠난 과학자들이 알게 된 사실들을 여러분들께 조심스럽게 말씀드립니다. 이 지식들은 언제든지 훗날 새로운 발견으로 반증될 수 있는 지식들이지만, ‘지금 우리가 이해하고 있는 인간’에 대한 여러 단편적인 진실들이 담겨 있습니다.\n인간의 숲 속으로 들어가 인간의... 처음 해보는 일은 계획할 수 없습니다. 혁신은 계획으로 이루어지지 않습니다. 혁신은 다양한 시도를 하고 계획을 끊임없이 수정해나가는 과정에서 이루어집니다. 중요한 건 계획을 완수하는 것이 아니라 목표를 완수하는 것입니다. 우리는 목표를 완수하기 위해 계획을 끊임없이 수정하는 법을 배워야 합니다. -「첫 번째 발자국, 선택하는 동안 뇌에서는 무슨 일이 벌어지는가」 ‘나는 무엇에서 즐거움을 얻는 사람인가?’라는 질문은 나는 무엇을 지향하는 사람인지를 알려줍니다. ‘나는 무슨 일을 하며 살아야 할까’라는 질문에 대답하려면, 내 즐거움의 원천, 놀이의 시간을 들여다보아야 합니다. -「네 번째 발자국, 인간에게 놀이란 무엇습관이라는 안락함 속에서는 평화롭고 예측 가능한 삶을 영위할 수 있지요. 습관의 틀을 벗어나려는 노력은 버겁습니다. 때문에 인생의 리셋도 어렵습니다. 새로고침을 신경과학적으로 해석해보면 나쁜 습관, 뻔한 일상으로부터 벗어나려는 시도입니다. 자기와 다른 분야에 있는, 다른 관심을 가진 사람들을 만나려고 의도적으로 노력하지 않으면, 그런 사람을 만날 가능성은 점점 적어집니다. 불편함을 견디면서 새로운 사람과 이야기하는 걸 즐기면서 살지 않으면, 새로고침은 점점 어려워집니다. 나쁜 습관, 틀에 박힌 일상으로부터 벗어나 삶을 새롭게 뒤바꿀 수 있는 신선한 자극이 있는 곳으로 먼저 여러분이 움직여야 합니다. -「다섯 번째 발자국, 우리 뇌도 ‘새로고침’할 수 있을까」 제가 오늘 미신이라는 주제를 환기하는 이유는 무엇보다도, 너무도 소중한 우리의 삶이 불합리한 요소들에 영향을 받고 있기 때문입니다. 왜 우리는 삶을 구속하는 비이성적인 믿음이 우리를 지배하는 것을 허락하고 있을까요? 내 삶은 내가 하기 나름이고, 나의 온전한 의지에 좌우된다는 고귀한 믿음을 왜 우리는 스스로 기꺼이, 너무나도 쉽게 포기하는 걸까요? -「여섯 번째 발자국, 우리는 왜 미신에 빠져드는가」 '

# %%
sentence = data['story'].apply(lambda x : re.sub('[^a-zA-Z|ㄱ-ㅣ가-힣|. ]+','', x))

# %%
sentence
# Out:
# 0      영원한 탐구 대상인 인간이라는 숲을 이해하기 위해 미지의 탐험을 떠난 과학자들이 알...
# 1      P.  시간은 나 내 나무에 대한 나의 눈 그리고 내 나무가 자신을 보는 눈에 대한...
# 2      탐험의 욕구는 인간의 본성이다. 우리는 나그네로 시작했으며 나그네로 남아 있다. 인...
# 3      뇌는 계속해서 우울한 상태를 유지하는 방향으로 생각하고 행동하는 경향이 있다. 우울...
# 4      지금 우리에게 다소 어려운 문제들도 언젠가는 상식이 될 것입니다. 오늘날 인간이 가...
#                              ...
# 303    현대 사회와 현대 도시인의 일상을 통해 마음과 본능 욕망의 진짜 얼굴을 낱낱이 파헤...
# 304    사실 고등동물의 경우는 그들이 질서 정연한 것들을 먹이로 삼고 있다는 것을 우리는 ...
# 305    그동안 쉽고 재미있는 수학 이야기로 독자와 친근하게 소통했던 안소영 저자는 이번 책...
# 306    브로콜리에서 프랙털을 빗방울에서 기하학을 종소리에서 순열을 발견할 수 있는 흥미로운...
# 307    적합한 OTC를 단시간 내에 선택 및 복약지도를 해야 하는 약사를 위한 일반의약품 ...
# Name: story, Length: 297, dtype: object

# %%
from konlpy.tag import Komoran
komo = Komoran()

# %% [markdown]
# # 문장 나눈거

# %%
ts=[]

# %%
for tag,ss in zip(data['name'],sentence):
    tmp=ss.split('.')
    ttmp=[]
    for i in tmp:
        if(len(re.sub('[^a-zA-Z|ㄱ-ㅣ가-힣]+','', i))!=0):
            ttmp.append(i)
    for sss in ttmp:
        ts.append([tag,komo.nouns(sss)])

# %%
ts=ts*20

# %%
len(ts)
# Out:
# 104860

# %%
from gensim.models.doc2vec import TaggedDocument

class Doc2VecCorpus:
    def __init__(self, ts):
        self.ts = ts
    def __iter__(self):
        for name,sentence in ts:
            if(len(sentence)>0):
                yield TaggedDocument(
                    words = sentence,
                    tags = [name])

# %%
doc2vec_corpus = Doc2VecCorpus(ts)

# %%
doc2vec_corpus = Doc2VecCorpus(ts)
from gensim.models import Doc2Vec

doc2vec_model = Doc2Vec(doc2vec_corpus)

# %%
for idx, doctag in sorted(doc2vec_model.docvecs.doctags.items(), key=lambda x:x[1].offset):
    print(idx, doctag)
# Out:
# 열두 발자국 Doctag(offset=0, word_count=2840, doc_count=380)
# 랩 걸 Doctag(offset=1, word_count=3360, doc_count=520)
# 코스모스 Doctag(offset=2, word_count=3000, doc_count=560)
# 우울할 땐 뇌과학 Doctag(offset=3, word_count=3460, doc_count=560)
# 수학이 필요한 순간 Doctag(offset=4, word_count=2520, doc_count=360)
# 떨림과 울림 Doctag(offset=5, word_count=4320, doc_count=700)
# 저도 과학은 어렵습니다만 Doctag(offset=6, word_count=2500, doc_count=480)
# 침묵의 봄 Doctag(offset=7, word_count=520, doc_count=100)
# 이기적 유전자 Doctag(offset=8, word_count=5060, doc_count=640)
# 정재승의 과학 콘서트 Doctag(offset=9, word_count=4340, doc_count=420)
# 미스터리 작가를 위한 법의학 Q&A Doctag(offset=10, word_count=3140, doc_count=440)
# 의식의 강 Doctag(offset=11, word_count=5520, doc_count=560)
# 도구와 기계의 원리 Now Doctag(offset=12, word_count=1900, doc_count=20)
# 놀라운 인체의 원리 Doctag(offset=13, word_count=1980, doc_count=20)
# 만화로 배우는 곤충의 진화 Doctag(offset=14, word_count=860, doc_count=20)
# 아내를 모자로 착각한 남자 Doctag(offset=15, word_count=4880, doc_count=920)
# 알고리즘, 인생을 계산하다 Doctag(offset=16, word_count=1080, doc_count=200)
# 야밤의 공대생 만화 Doctag(offset=17, word_count=1800, doc_count=20)
# 원더풀 사이언스 Doctag(offset=18, word_count=2080, doc_count=380)
# 김상욱의 양자 공부 Doctag(offset=19, word_count=2920, doc_count=400)
# 보이는 세상은 실재가 아니다 Doctag(offset=20, word_count=6500, doc_count=820)
# 스케일 : 생물.도시.기업의 성장과 죽음에 관한 보편 법칙 Doctag(offset=21, word_count=3580, doc_count=400)
# 위험한 과학책 Doctag(offset=22, word_count=10820, doc_count=1380)
# 세상을 만드는 글자, 코딩 Doctag(offset=23, word_count=6120, doc_count=880)
# 세계사를 바꾼 10가지 약 Doctag(offset=24, word_count=9820, doc_count=1220)
# 날마다 천체 물리 Doctag(offset=25, word_count=2120, doc_count=20)
# 그림으로 보는 시간의 역사 Doctag(offset=26, word_count=460, doc_count=100)
# 늙지 않는 비밀 Doctag(offset=27, word_count=5020, doc_count=700)
# 물리·화학 사전 Doctag(offset=28, word_count=1700, doc_count=20)
# 스티븐 호킹의 블랙홀 Doctag(offset=29, word_count=4360, doc_count=900)
# 인듀어 Doctag(offset=30, word_count=6320, doc_count=540)
# 나무의 노래 Doctag(offset=31, word_count=2880, doc_count=380)
# 미적분으로 바라본 하루 Doctag(offset=32, word_count=780, doc_count=20)
# 이 문제 풀 수 있겠어? Doctag(offset=33, word_count=5580, doc_count=880)
# 대량살상수학무기 Doctag(offset=34, word_count=7360, doc_count=920)
# 비커 군과 실험실 친구들 Doctag(offset=35, word_count=4500, doc_count=540)
# 전체를 보는 방법 Doctag(offset=36, word_count=4420, doc_count=440)
# 더 브레인 Doctag(offset=37, word_count=3620, doc_count=480)
# 우리 몸 연대기 Doctag(offset=38, word_count=3400, doc_count=340)
# 마우나케아의 어떤 밤 Doctag(offset=39, word_count=4820, doc_count=720)
# 거의 모든 것의 역사 Doctag(offset=40, word_count=1860, doc_count=260)
# 숲은 생각한다 Doctag(offset=41, word_count=3500, doc_count=460)
# 부분과 전체 Doctag(offset=42, word_count=400, doc_count=40)
# 수학 사전 Doctag(offset=43, word_count=1620, doc_count=20)
# 음식해부도감 Doctag(offset=44, word_count=4600, doc_count=580)
# 자연의 비밀 네트워크 Doctag(offset=45, word_count=4760, doc_count=680)
# 도덕의 기원 Doctag(offset=46, word_count=4240, doc_count=400)
# 우리 몸 오류 보고서 Doctag(offset=47, word_count=1860, doc_count=20)
# 재밌어서 밤새읽는 화학 이야기 Doctag(offset=48, word_count=3960, doc_count=500)
# 페르마의 마지막 정리 Doctag(offset=49, word_count=3040, doc_count=400)
# 인류의 기원 Doctag(offset=50, word_count=3040, doc_count=400)
# 나의 수학 사춘기 Doctag(offset=51, word_count=2300, doc_count=20)
# 물리의 정석: 양자 역학 편 Doctag(offset=52, word_count=1800, doc_count=20)
# 만들어진 신 Doctag(offset=53, word_count=3580, doc_count=500)
# 산책자를 위한 자연수업 Doctag(offset=54, word_count=2900, doc_count=420)
# 꽃도감 Doctag(offset=55, word_count=1620, doc_count=20)
# 메스를 잡다 Doctag(offset=56, word_count=3820, doc_count=400)
# 과학자가 되는 방법 Doctag(offset=57, word_count=760, doc_count=120)
# 미래를 읽다 과학이슈 11 Season 6 Doctag(offset=58, word_count=1620, doc_count=20)
# 세상에서 가장 쉬운 통계학입문 Doctag(offset=59, word_count=3620, doc_count=460)
# 왜 맛있을까 Doctag(offset=60, word_count=4040, doc_count=560)
# 창백한 푸른 점 Doctag(offset=61, word_count=1200, doc_count=120)
# 진짜 우주를 여행하는 히치하이커를 위한 안내서 Doctag(offset=62, word_count=200, doc_count=40)
# 스스로 치유하는 뇌 Doctag(offset=63, word_count=6260, doc_count=820)
# 통제 불능 Doctag(offset=64, word_count=5860, doc_count=840)
# 고양이처럼 생각하기 Doctag(offset=65, word_count=2920, doc_count=20)
# 어떻게 일할 것인가 Doctag(offset=66, word_count=5820, doc_count=900)
# 물리의 정석: 고전 역학 편 Doctag(offset=67, word_count=240, doc_count=40)
# 엔트로피 Doctag(offset=68, word_count=3020, doc_count=360)
# 정원생활자의 열두 달 Doctag(offset=69, word_count=4900, doc_count=360)
# 우연은 얼마나 내 삶을 지배하는가 Doctag(offset=70, word_count=1860, doc_count=280)
# 멘사 스도쿠 프리미어 500 Doctag(offset=71, word_count=800, doc_count=20)
# 틀리지 않는 법 Doctag(offset=72, word_count=2800, doc_count=500)
# 그리고 당신이 죽는다면 Doctag(offset=73, word_count=4820, doc_count=940)
# THE FOOD LAB 더 푸드 랩 : 더 나은 요리를 위한 주방 과학의 모든것! Doctag(offset=74, word_count=660, doc_count=40)
# 왜 종교는 과학이 되려 하는가 Doctag(offset=75, word_count=1600, doc_count=20)
# 엘러건트 유니버스 Doctag(offset=76, word_count=540, doc_count=40)
# 크리스퍼가 온다 Doctag(offset=77, word_count=3340, doc_count=380)
# 인간은 어떻게 서로를 공감하는가 Doctag(offset=78, word_count=1860, doc_count=20)
# 박문호 박사의 뇌과학 공부 Doctag(offset=79, word_count=4980, doc_count=700)
# 길 위의 수학자 Doctag(offset=80, word_count=1260, doc_count=20)
# NEW 재미있는 물리여행 Doctag(offset=81, word_count=1540, doc_count=20)
# 숲에서 우주를 보다 Doctag(offset=82, word_count=1660, doc_count=20)
# 자동차 구조 교과서 Doctag(offset=83, word_count=1800, doc_count=20)
# 처음 배우는 딥러닝 수학 Doctag(offset=84, word_count=760, doc_count=20)
# 놓아 버림 Doctag(offset=85, word_count=1620, doc_count=320)
# 너무 재밌어서 잠 못 드는 물리 이야기 Doctag(offset=86, word_count=1220, doc_count=20)
# 늙어감의 기술 Doctag(offset=87, word_count=3120, doc_count=280)
# 수학, 인문으로 수를 읽다 Doctag(offset=88, word_count=3400, doc_count=500)
# 청소년을 위한 시간의 역사 Doctag(offset=89, word_count=2960, doc_count=380)
# 덜미, 완전범죄는 없다 1 Doctag(offset=90, word_count=1400, doc_count=20)
# 과학혁명의 구조 Doctag(offset=91, word_count=1440, doc_count=20)
# 얼굴은 인간을 어떻게 진화시켰는가 Doctag(offset=92, word_count=2740, doc_count=320)
# 바이오사이언스의 이해 Doctag(offset=93, word_count=8620, doc_count=1140)
# 모든 순간의 물리학 Doctag(offset=94, word_count=3580, doc_count=460)
# 생각의 기원 Doctag(offset=95, word_count=2420, doc_count=20)
# 일곱 원소 이야기 Doctag(offset=96, word_count=4360, doc_count=440)
# 도덕의 궤적 Doctag(offset=97, word_count=4560, doc_count=400)
# 만화로 아주 쉽게 배우는 통계학 Doctag(offset=98, word_count=4900, doc_count=680)
# 맥스 테그마크의 라이프 3.0 Doctag(offset=99, word_count=6800, doc_count=960)
# 중고등학교 화학 Doctag(offset=100, word_count=2300, doc_count=20)
# 통계학, 빅데이터를 잡다 Doctag(offset=101, word_count=2060, doc_count=220)
# 우주의 구조 Doctag(offset=102, word_count=5080, doc_count=500)
# 지능의 탄생 Doctag(offset=103, word_count=660, doc_count=80)
# 악의 마음을 읽는 자들 Doctag(offset=104, word_count=4700, doc_count=580)
# 멘사 수학 퍼즐 Doctag(offset=105, word_count=280, doc_count=20)
# 뇌 이야기 Doctag(offset=106, word_count=6300, doc_count=820)
# 우리는 차별하기 위해 태어났다 Doctag(offset=107, word_count=1640, doc_count=200)
# 자연의 예술적 형상 Doctag(offset=108, word_count=2200, doc_count=20)
# 정글 Doctag(offset=109, word_count=660, doc_count=20)
# 소설처럼 아름다운 수학 이야기 Doctag(offset=110, word_count=1820, doc_count=20)
# 문경수의 제주 과학 탐험 Doctag(offset=111, word_count=4340, doc_count=680)
# 세상에서 가장 쉬운 양자역학 수업 Doctag(offset=112, word_count=3300, doc_count=480)
# 새빨간 거짓말, 통계 Doctag(offset=113, word_count=460, doc_count=100)
# 미술관에 간 수학자 Doctag(offset=114, word_count=940, doc_count=20)
# 물리가 쉬워지는 미적분 Doctag(offset=115, word_count=3160, doc_count=440)
# 선형대수와 군 Doctag(offset=116, word_count=940, doc_count=20)
# 자동차 정비 교과서 Doctag(offset=117, word_count=960, doc_count=20)
# 뇌와 뉴런 (신경 세포) Doctag(offset=118, word_count=2300, doc_count=20)
# 과학이라는 헛소리 Doctag(offset=119, word_count=3480, doc_count=440)
# 동물 해방 Doctag(offset=120, word_count=620, doc_count=60)
# 종의 기원 Doctag(offset=121, word_count=820, doc_count=20)
# 재밌어서 밤새읽는 수학 이야기 Doctag(offset=122, word_count=4380, doc_count=940)
# 파인만의 여섯가지 물리 이야기 Doctag(offset=123, word_count=440, doc_count=100)
# 장하석의 과학, 철학을 만나다 Doctag(offset=124, word_count=2340, doc_count=20)
# 제대로 시작하는 기초 통계학 : Excel 활용 Doctag(offset=125, word_count=620, doc_count=20)
# 수학자의 공부 Doctag(offset=126, word_count=8900, doc_count=2060)
# 물속을 나는 새 Doctag(offset=127, word_count=2320, doc_count=20)
# 인듀어런스 Doctag(offset=128, word_count=6900, doc_count=1200)
# 문명과 수학 Doctag(offset=129, word_count=4200, doc_count=660)
# 김상욱의 과학공부 Doctag(offset=130, word_count=4360, doc_count=720)
# 멘사코리아 논리 퍼즐 Doctag(offset=131, word_count=800, doc_count=20)
# 수학의 언어로 세상을 본다면 Doctag(offset=132, word_count=5580, doc_count=900)
# 슈퍼 스도쿠 500문제 초급 중급 Doctag(offset=133, word_count=420, doc_count=20)
# 세상에서 가장 쉬운 베이즈통계학 입문 Doctag(offset=134, word_count=4720, doc_count=500)
# 유사과학 탐구영역 1 Doctag(offset=135, word_count=980, doc_count=20)
# 미술관에 간 화학자 1 Doctag(offset=136, word_count=1800, doc_count=20)
# 사파리 Doctag(offset=137, word_count=740, doc_count=20)
# 비행기 구조 교과서 Doctag(offset=138, word_count=660, doc_count=20)
# 프로그래머를 위한 선형대수 Doctag(offset=139, word_count=1200, doc_count=20)
# 인도 베다수학 베스트 3종 세트 Doctag(offset=140, word_count=1120, doc_count=20)
# 뷰티풀 퀘스천 Doctag(offset=141, word_count=6140, doc_count=740)
# 나는 과학이 말하는 성차별이 불편합니다 Doctag(offset=142, word_count=2560, doc_count=320)
# 나는 미생물과 산다 Doctag(offset=143, word_count=3660, doc_count=540)
# 악기 구조 교과서 (2018 한국과학창의재단 우수과학도서) Doctag(offset=144, word_count=1340, doc_count=20)
# 면역에 관하여 Doctag(offset=145, word_count=2140, doc_count=220)
# 물리학자는 영화에서 과학을 본다 Doctag(offset=146, word_count=4840, doc_count=440)
# 바이오센트리즘 Doctag(offset=147, word_count=3440, doc_count=520)
# 우리 본성의 선한 천사 Doctag(offset=148, word_count=3420, doc_count=480)
# 인공지능의 시대, 인간을 다시 묻다 Doctag(offset=149, word_count=8120, doc_count=1100)
# 알고리즘 라이프 Doctag(offset=150, word_count=4200, doc_count=600)
# 진화 : 모든 것을 설명하는 생명의 언어 Doctag(offset=151, word_count=3080, doc_count=360)
# 수학의 감각 Doctag(offset=152, word_count=2780, doc_count=580)
# 수학 언어로 문화재를 읽다 Doctag(offset=153, word_count=1280, doc_count=20)
# 생명이 있는 것은 다 아름답다 Doctag(offset=154, word_count=2420, doc_count=440)
# 시민의 물리학 Doctag(offset=155, word_count=5020, doc_count=520)
# 특이점이 온다 Doctag(offset=156, word_count=520, doc_count=60)
# 스핀 Doctag(offset=157, word_count=2180, doc_count=20)
# 랜들 먼로의 친절한 과학 그림책 Doctag(offset=158, word_count=5200, doc_count=960)
# 역사를 바꾼 17가지 화학 이야기 1 Doctag(offset=159, word_count=600, doc_count=80)
# 미술관에 간 의학자 Doctag(offset=160, word_count=1920, doc_count=20)
# 동물의 무기 Doctag(offset=161, word_count=5380, doc_count=840)
# 블랙 스완 Doctag(offset=162, word_count=1780, doc_count=20)
# 비행기 조종 교과서 Doctag(offset=163, word_count=2860, doc_count=20)
# 과학자들 1 Doctag(offset=164, word_count=1980, doc_count=20)
# 찻잔 속 물리학 Doctag(offset=165, word_count=5900, doc_count=1100)
# 작은 집 짓기 해부도감 Doctag(offset=166, word_count=3980, doc_count=580)
# 싸우는 식물 Doctag(offset=167, word_count=2220, doc_count=20)
# 물리학은 처음인데요 Doctag(offset=168, word_count=2680, doc_count=460)
# 김대식의 인간 vs 기계 Doctag(offset=169, word_count=5700, doc_count=980)
# 비커 군과 친구들의 유쾌한 화학실험 Doctag(offset=170, word_count=2560, doc_count=320)
# 모든 것의 기원 Doctag(offset=171, word_count=1780, doc_count=280)
# 인간의 본능 Doctag(offset=172, word_count=11920, doc_count=1460)
# 같기도 하고 아니 같기도 하고 Doctag(offset=173, word_count=1140, doc_count=20)
# 의식 혁명 Doctag(offset=174, word_count=640, doc_count=100)
# 음식과 요리 Doctag(offset=175, word_count=7880, doc_count=860)
# 내 머릿속에선 무슨 일이 벌어지고 있을까 Doctag(offset=176, word_count=4060, doc_count=540)
# 천문대의 시간 천문학자의 하늘 Doctag(offset=177, word_count=1820, doc_count=20)
# 이중나선 Doctag(offset=178, word_count=480, doc_count=40)
# 인공지능을 위한 수학 Doctag(offset=179, word_count=680, doc_count=20)
# 물리와 철학 Doctag(offset=180, word_count=680, doc_count=80)
# 온 더 무브 Doctag(offset=181, word_count=3900, doc_count=700)
# 재밌어서 밤새읽는 물리 이야기 Doctag(offset=182, word_count=3560, doc_count=420)
# 뇌과학자는 영화에서 인간을 본다 Doctag(offset=183, word_count=2280, doc_count=240)
# 한국의 들꽃 Doctag(offset=184, word_count=3400, doc_count=20)
# 한국전문소생술(KALS) Doctag(offset=185, word_count=1220, doc_count=20)
# 괴델, 에셔, 바흐 Doctag(offset=186, word_count=1640, doc_count=20)
# 만화로 보는 우주 최강의 물리학 토크 Doctag(offset=187, word_count=2160, doc_count=20)
# 데이터를 철학하다 Doctag(offset=188, word_count=5020, doc_count=620)
# 위대하고 위험한 약 이야기 Doctag(offset=189, word_count=540, doc_count=80)
# 파인만 씨, 농담도 잘하시네! 1 Doctag(offset=190, word_count=2440, doc_count=20)
# 게놈 익스프레스 Doctag(offset=191, word_count=1180, doc_count=200)
# 그래비티 익스프레스 Doctag(offset=192, word_count=960, doc_count=20)
# 고맙습니다 (일반판) Doctag(offset=193, word_count=3260, doc_count=420)
# 알고리즘 산책 Doctag(offset=194, word_count=560, doc_count=100)
# 사라진 스푼 Doctag(offset=195, word_count=5340, doc_count=560)
# 나무 쉽게 찾기 Doctag(offset=196, word_count=1380, doc_count=20)
# 커피 얼룩의 비밀 Doctag(offset=197, word_count=1320, doc_count=20)
# 아톰 익스프레스 Doctag(offset=198, word_count=1760, doc_count=240)
# 케네스 포드의 양자물리학 강의 Doctag(offset=199, word_count=1220, doc_count=20)
# 내 머릿속에 누군가 있다 Doctag(offset=200, word_count=2000, doc_count=260)
# 완전 도해 주기율표 Doctag(offset=201, word_count=2620, doc_count=20)
# 에덴의 용 Doctag(offset=202, word_count=10020, doc_count=1120)
# 약의 과학 지식 Doctag(offset=203, word_count=1140, doc_count=20)
# 4차 산업혁명이라는 유령 Doctag(offset=204, word_count=2860, doc_count=20)
# 마음의 과학 Doctag(offset=205, word_count=3080, doc_count=320)
# 비행기 엔진 교과서 Doctag(offset=206, word_count=640, doc_count=20)
# 이명현의 과학책방 Doctag(offset=207, word_count=2000, doc_count=340)
# 치유와 회복 Doctag(offset=208, word_count=3940, doc_count=600)
# 마음의 미래 Doctag(offset=209, word_count=6040, doc_count=840)
# 자동차 운전 교과서 Doctag(offset=210, word_count=1100, doc_count=20)
# 빈 서판 Doctag(offset=211, word_count=1960, doc_count=360)
# 이성의 진화 Doctag(offset=212, word_count=480, doc_count=80)
# 나를 넘다 Doctag(offset=213, word_count=9640, doc_count=1000)
# 춤추는 식물 Doctag(offset=214, word_count=4320, doc_count=420)
# 넘버스 Doctag(offset=215, word_count=2460, doc_count=540)
# 침팬지 폴리틱스 Doctag(offset=216, word_count=1380, doc_count=20)
# 뉴로트라이브 Doctag(offset=217, word_count=8420, doc_count=800)
# 사람 몸의 구조 Doctag(offset=218, word_count=2060, doc_count=20)
# 인공 지능 Doctag(offset=219, word_count=1080, doc_count=20)
# 1.4킬로그램의 우주, 뇌 Doctag(offset=220, word_count=2000, doc_count=20)
# 세상을 이루는 모든 원소 118 Doctag(offset=221, word_count=1580, doc_count=20)
# 올 댓 허브 Doctag(offset=222, word_count=3360, doc_count=280)
# 심폐소생술과 전문 심장소생술 Doctag(offset=223, word_count=400, doc_count=20)
# 수포유 : 나의 수학 사춘기 워크북 Doctag(offset=224, word_count=1340, doc_count=20)
# 소리의 과학 Doctag(offset=225, word_count=2540, doc_count=240)
# 기발한 과학책 Doctag(offset=226, word_count=1600, doc_count=20)
# 진화심리학 Doctag(offset=227, word_count=4160, doc_count=320)
# 우리는 왜 개는 사랑하고 돼지는 먹고 소는 신을까 Doctag(offset=228, word_count=920, doc_count=140)
# 공학이란 무엇인가 Doctag(offset=229, word_count=4760, doc_count=800)
# 초공간 Doctag(offset=230, word_count=2840, doc_count=380)
# 미분과 적분 Doctag(offset=231, word_count=160, doc_count=40)
# 화학에서 인생을 배우다 Doctag(offset=232, word_count=5560, doc_count=500)
# 짧고 쉽게 쓴 '시간의 역사' Doctag(offset=233, word_count=580, doc_count=40)
# 스탠퍼드 수학공부법 Doctag(offset=234, word_count=2040, doc_count=20)
# 빛의 물리학 Doctag(offset=235, word_count=2140, doc_count=500)
# 위대한 설계 Doctag(offset=236, word_count=1420, doc_count=20)
# 하리하라의 바이오 사이언스 : 유전과 생명공학 Doctag(offset=237, word_count=3040, doc_count=320)
# 신은 주사위 놀이를 하지 않는다 Doctag(offset=238, word_count=560, doc_count=120)
# 생명, 경계에 서다 Doctag(offset=239, word_count=1680, doc_count=160)
# 세상의 모든 원소 118 (특별판) Doctag(offset=240, word_count=1280, doc_count=20)
# 나무 수업 Doctag(offset=241, word_count=7740, doc_count=1300)
# 음식 원리 Doctag(offset=242, word_count=1400, doc_count=20)
# 9번째 지능 Doctag(offset=243, word_count=5020, doc_count=660)
# DNA 혁명 크리스퍼 유전자가위 Doctag(offset=244, word_count=5760, doc_count=520)
# 늑대인간 마을에서 탈출 Doctag(offset=245, word_count=520, doc_count=100)
# 컨버전스 Doctag(offset=246, word_count=3380, doc_count=340)
# 돈의 원리 Doctag(offset=247, word_count=2020, doc_count=20)
# 자연 기계 Doctag(offset=248, word_count=1420, doc_count=20)
# 어쩌다 우리는 환자가 되었나 Doctag(offset=249, word_count=860, doc_count=20)
# 한국의 나무 Doctag(offset=250, word_count=2660, doc_count=20)
# 과학자들 2 Doctag(offset=251, word_count=2600, doc_count=20)
# 일상에 숨겨진 수학 이야기 Doctag(offset=252, word_count=1740, doc_count=20)
# 단단한 과학 공부 Doctag(offset=253, word_count=1580, doc_count=20)
# 과학자를 울린 과학책 Doctag(offset=254, word_count=2120, doc_count=260)
# 박경미의 수학콘서트 플러스 Doctag(offset=255, word_count=4740, doc_count=440)
# 소자본 태양광발전소 Doctag(offset=256, word_count=4020, doc_count=300)
# 내 속엔 미생물이 너무도 많아 Doctag(offset=257, word_count=4380, doc_count=460)
# 탱크 북 Doctag(offset=258, word_count=700, doc_count=60)
# 과학자들 3 Doctag(offset=259, word_count=2580, doc_count=20)
# 멘사 스도쿠 챌린지 Doctag(offset=260, word_count=800, doc_count=20)
# 색맹의 섬 (4종 중 1종 표지 랜덤) Doctag(offset=261, word_count=2960, doc_count=380)
# 통계의 미학 Doctag(offset=262, word_count=480, doc_count=80)
# 인체 원리 Doctag(offset=263, word_count=1620, doc_count=20)
# 숲 읽어주는 남자 Doctag(offset=264, word_count=4860, doc_count=780)
# 생각한다면 과학자처럼 Doctag(offset=265, word_count=5220, doc_count=800)
# 문과생을 위한 이과 센스 Doctag(offset=266, word_count=5600, doc_count=600)
# 10퍼센트 인간 Doctag(offset=267, word_count=5720, doc_count=760)
# 우리 역사 속 수학 이야기 Doctag(offset=268, word_count=1020, doc_count=20)
# 눈먼 시계공 Doctag(offset=269, word_count=400, doc_count=60)
# 두 얼굴의 백신 Doctag(offset=270, word_count=1820, doc_count=20)
# 우리 만난 적 있나요? Doctag(offset=271, word_count=3400, doc_count=560)
# 미생물군 유전체는 내몸을 어떻게 바꾸는가 Doctag(offset=272, word_count=7040, doc_count=540)
# 재밌어서 밤새읽는 지구과학 이야기 Doctag(offset=273, word_count=1440, doc_count=20)
# 공간이 사람을 움직인다 Doctag(offset=274, word_count=420, doc_count=60)
# 협력의 진화 Doctag(offset=275, word_count=1340, doc_count=180)
# 과학기술의 일상사 Doctag(offset=276, word_count=4420, doc_count=440)
# 미적분학 1+ Doctag(offset=277, word_count=1600, doc_count=20)
# 자연이 마음을 살린다 Doctag(offset=278, word_count=3940, doc_count=460)
# 화학으로 이루어진 세상 Doctag(offset=279, word_count=540, doc_count=120)
# 하리하라의 과학블로그 Doctag(offset=280, word_count=420, doc_count=100)
# 코스모스 오디세이 Doctag(offset=281, word_count=440, doc_count=20)
# 에이다, 당신이군요. 최초의 프로그래머 Doctag(offset=282, word_count=1420, doc_count=20)
# 우주, 시간, 그 너머 Doctag(offset=283, word_count=5800, doc_count=980)
# 과학자도 모르는 위험한 과학기술 Doctag(offset=284, word_count=5020, doc_count=620)
# 미생물에 관한 거의 모든 것 Doctag(offset=285, word_count=3340, doc_count=380)
# 클래식 파인만 Doctag(offset=286, word_count=2340, doc_count=20)
# 정리하는 뇌 Doctag(offset=287, word_count=4100, doc_count=540)
# 욕망의 진화 Doctag(offset=288, word_count=5340, doc_count=580)
# 수학으로 힐링하기 Doctag(offset=289, word_count=3080, doc_count=780)
# 다윈의 식탁 Doctag(offset=290, word_count=3180, doc_count=460)
# 일렉트릭 유니버스 Doctag(offset=291, word_count=1320, doc_count=20)
# 오래된 연장통 Doctag(offset=292, word_count=2300, doc_count=20)
# 생물과 무생물 사이 Doctag(offset=293, word_count=2620, doc_count=360)
# 배낭에서 꺼낸 수학 Doctag(offset=294, word_count=1360, doc_count=20)
# 세상을 움직이는 수학개념 100 Doctag(offset=295, word_count=1580, doc_count=20)
# 맞춤 OTC 선택가이드 Doctag(offset=296, word_count=1700, doc_count=20)

# %%
doc2vec_model.docvecs.most_similar('더 브레인')
# Out:
# [('인간은 어떻게 서로를 공감하는가', 0.5434907674789429),
#  ('내 머릿속에선 무슨 일이 벌어지고 있을까', 0.521960437297821),
#  ('정리하는 뇌', 0.4905798137187958),
#  ('협력의 진화', 0.49001389741897583),
#  ('도덕의 기원', 0.4861239194869995),
#  ('뇌 이야기', 0.48479801416397095),
#  ('얼굴은 인간을 어떻게 진화시켰는가', 0.47380244731903076),
#  ('아내를 모자로 착각한 남자', 0.4716000258922577),
#  ('박문호 박사의 뇌과학 공부', 0.4684170186519623),
#  ('거의 모든 것의 역사', 0.4540971517562866)]

# %%
ddd = pd.read_csv('과학데이터최종진짜.csv',encoding='utf-8',index_col=0)

# %%
ssentence = ddd['story'].apply(lambda x : re.sub('[^a-zA-Z|ㄱ-ㅣ가-힣|. ]+','', x))

# %%
ssentence
# Out:
# 0      영원한 탐구 대상인 인간이라는 숲을 이해하기 위해 미지의 탐험을 떠난 과학자들이 알...
# 1      P.  시간은 나 내 나무에 대한 나의 눈 그리고 내 나무가 자신을 보는 눈에 대한...
# 2      탐험의 욕구는 인간의 본성이다. 우리는 나그네로 시작했으며 나그네로 남아 있다. 인...
# 3      뇌는 계속해서 우울한 상태를 유지하는 방향으로 생각하고 행동하는 경향이 있다. 우울...
# 4      지금 우리에게 다소 어려운 문제들도 언젠가는 상식이 될 것입니다. 오늘날 인간이 가...
#                              ...
# 303    현대 사회와 현대 도시인의 일상을 통해 마음과 본능 욕망의 진짜 얼굴을 낱낱이 파헤...
# 304    사실 고등동물의 경우는 그들이 질서 정연한 것들을 먹이로 삼고 있다는 것을 우리는 ...
# 305    그동안 쉽고 재미있는 수학 이야기로 독자와 친근하게 소통했던 안소영 저자는 이번 책...
# 306    브로콜리에서 프랙털을 빗방울에서 기하학을 종소리에서 순열을 발견할 수 있는 흥미로운...
# 307    적합한 OTC를 단시간 내에 선택 및 복약지도를 해야 하는 약사를 위한 일반의약품 ...
# Name: story, Length: 297, dtype: object

# %% [markdown]
# # 여기는 문장으로 안나누고 하기

# %%
tts=[]

# %%
for tag,ss in zip(ddd['name'],sentence):
        tts.append([tag,komo.nouns(ss)])

# %%
tts=tts*20

# %%
doc2vec_corpus2 = Doc2VecCorpus(tts)
from gensim.models import Doc2Vec

doc2vec_model2 = Doc2Vec(doc2vec_corpus2)

# %%
doc2vec_model2.docvecs.most_similar('뇌와 뉴런 (신경 세포)')
# Out:
# [('인간은 어떻게 서로를 공감하는가', 0.674464225769043),
#  ('인공 지능', 0.58847975730896),
#  ('약의 과학 지식', 0.5615112781524658),
#  ('중고등학교 화학', 0.5552451610565186),
#  ('공간이 사람을 움직인다', 0.5462380051612854),
#  ('맞춤 OTC 선택가이드', 0.5216326713562012),
#  ('이성의 진화', 0.5086532831192017),
#  ('자동차 운전 교과서', 0.5070870518684387),
#  ('에이다, 당신이군요. 최초의 프로그래머', 0.5041801929473877),
#  ('처음 배우는 딥러닝 수학', 0.5003759264945984)]
